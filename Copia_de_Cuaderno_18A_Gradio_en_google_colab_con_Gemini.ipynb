# %% [markdown]
# <a href="https://colab.research.google.com/github/anfalear/practicas/blob/main/Copia_de_Cuaderno_18A_Gradio_en_google_colab_con_Gemini.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-genai

# %%
from google import genai
import gradio as gr
import os

os.environ["GEMINI_API_KEY"] = "AIzaSyBw5wH3GzFOH0qoCxWlVemgGeshR_6PDPY"

glosa="GLOSA: YO IR SORDO ADULO VISITAR"
# The client gets the API key from the environment variable `GEMINI_API_KEY`.
client = genai.Client()

prompt=""" La siguiente glosas en lenguaje de sordos. Quiero convertirla en una frases completa y gramaticalmente correctas en español
hablado, de manera que sean fácilmente entendibles por personas que escuchan. Por favor, realiza la conversión y responder con la frase completa y en español.

Ejemplo de glosa:
CASA MÍA GRANDE
Ejemplo de salida deseada:
Mi casa es grande.
Tengo una casa grande.
Por favor, comienza con las siguientes glosas:"""


response = client.models.generate_content(
    model="gemini-2.5-flash", contents=prompt+" "+glosa
)
print(response.text)
# Out:
# Entendido. La glosa "YO IR SORDO ADULO VISITAR" se puede interpretar de varias maneras, pero la más común y natural, asumiendo que "ADULO" es una simplificación o errata de "ADULTO", es:
#
# **Voy a visitar a un sordo adulto.**
#
# O, para ser más inclusivo y general:
#
# **Voy a visitar a una persona sorda adulta.**

# %%
from google import genai
import gradio as gr
import os

# Configurar clave de API (asegúrate de poner la tuya)
os.environ["GEMINI_API_KEY"] = "AIzaSyBw5wH3GzFOH0qoCxWlVemgGeshR_6PDPY"

# Crear cliente Gemini
client = genai.Client()

# Crear un chat persistente con el modelo
chat = client.chats.create(model="gemini-2.5-flash")

# Función de respuesta para Gradio
def responder(mensaje, historia):
    try:
        # Enviar mensaje al modelo
        respuesta = chat.send_message(mensaje)
        # Añadir al historial
        historia = historia or []
        historia.append({"role": "user", "content": mensaje})
        historia.append({"role": "assistant", "content": respuesta.text})
        return historia
    except Exception as e:
        return [{"role": "assistant", "content": f"❌ Error: {e}"}]

# Interfaz de chat con formato 'messages'
demo = gr.ChatInterface(
    fn=responder,
    title=" Chat con Gemini 2.5 Flash",
    description="Chat interactivo con el modelo Gemini más reciente (API google.genai).",
    type="messages",
    examples=[
        {"role": "user", "content": "¿Qué es la inteligencia artificial?"},
        {"role": "user", "content": "Explica la diferencia entre IA y machine learning."}
    ]
)

demo.launch(share=True)
# Out:
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://b86ca7a28fdb6743ca.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://b86ca7a28fdb6743ca.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
