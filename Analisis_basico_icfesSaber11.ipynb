# %% [markdown]
# 1. Carga de librerías

# %%
# importar librerías

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# %% [markdown]
# 2. Carga y visualización de los datos

# %%
# Cargar el archivo CSV
df = pd.read_csv('datosicfessaber11202002.csv')

# Mostrar información general
print('Información del dataset:')
print(df.info())

# Visualizar las primeras filas
print('\nPrimeras filas:')
print(df.head())

# Estadísticas descriptivas
print('\nEstadísticas descriptivas:')
print(df.describe())
# Out:
# Información del dataset:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2000 entries, 0 to 1999
# Data columns (total 81 columns):
#  #   Column                         Non-Null Count  Dtype
# ---  ------                         --------------  -----
#  0   ESTU_TIPODOCUMENTO             2000 non-null   object
#  1   ESTU_NACIONALIDAD              2000 non-null   object
#  2   ESTU_GENERO                    2000 non-null   object
#  3   ESTU_FECHANACIMIENTO           2000 non-null   object
#  4   PERIODO                        2000 non-null   int64
#  5   ESTU_CONSECUTIVO               2000 non-null   object
#  6   ESTU_ESTUDIANTE                2000 non-null   object
#  7   ESTU_PAIS_RESIDE               2000 non-null   object
#  8   ESTU_TIENEETNIA                1990 non-null   object
#  9   ESTU_DEPTO_RESIDE              2000 non-null   object
#  10  ESTU_COD_RESIDE_DEPTO          2000 non-null   int64
#  11  ESTU_MCPIO_RESIDE              2000 non-null   object
#  12  ESTU_COD_RESIDE_MCPIO          2000 non-null   int64
#  13  FAMI_ESTRATOVIVIENDA           1941 non-null   object
#  14  FAMI_PERSONASHOGAR             1942 non-null   object
#  15  FAMI_CUARTOSHOGAR              1937 non-null   object
#  16  FAMI_EDUCACIONPADRE            1949 non-null   object
#  17  FAMI_EDUCACIONMADRE            1949 non-null   object
#  18  FAMI_TRABAJOLABORPADRE         1921 non-null   object
#  19  FAMI_TRABAJOLABORMADRE         1926 non-null   object
#  20  FAMI_TIENEINTERNET             1949 non-null   object
#  21  FAMI_TIENESERVICIOTV           1944 non-null   object
#  22  FAMI_TIENECOMPUTADOR           1919 non-null   object
#  23  FAMI_TIENELAVADORA             1935 non-null   object
#  24  FAMI_TIENEHORNOMICROOGAS       1932 non-null   object
#  25  FAMI_TIENEAUTOMOVIL            1931 non-null   object
#  26  FAMI_TIENEMOTOCICLETA          1937 non-null   object
#  27  FAMI_TIENECONSOLAVIDEOJUEGOS   1935 non-null   object
#  28  FAMI_NUMLIBROS                 1952 non-null   object
#  29  FAMI_COMELECHEDERIVADOS        1946 non-null   object
#  30  FAMI_COMECARNEPESCADOHUEVO     1936 non-null   object
#  31  FAMI_COMECEREALFRUTOSLEGUMBRE  1916 non-null   object
#  32  FAMI_SITUACIONECONOMICA        1937 non-null   object
#  33  ESTU_DEDICACIONLECTURADIARIA   1947 non-null   object
#  34  ESTU_DEDICACIONINTERNET        1948 non-null   object
#  35  ESTU_HORASSEMANATRABAJA        1932 non-null   object
#  36  ESTU_TIPOREMUNERACION          1926 non-null   object
#  37  COLE_CODIGO_ICFES              2000 non-null   int64
#  38  COLE_COD_DANE_ESTABLECIMIENTO  2000 non-null   float64
#  39  COLE_NOMBRE_ESTABLECIMIENTO    2000 non-null   object
#  40  COLE_GENERO                    2000 non-null   object
#  41  COLE_NATURALEZA                2000 non-null   object
#  42  COLE_CALENDARIO                2000 non-null   object
#  43  COLE_BILINGUE                  1651 non-null   object
#  44  COLE_CARACTER                  1950 non-null   object
#  45  COLE_COD_DANE_SEDE             2000 non-null   float64
#  46  COLE_NOMBRE_SEDE               2000 non-null   object
#  47  COLE_SEDE_PRINCIPAL            2000 non-null   object
#  48  COLE_AREA_UBICACION            2000 non-null   object
#  49  COLE_JORNADA                   2000 non-null   object
#  50  COLE_COD_MCPIO_UBICACION       2000 non-null   int64
#  51  COLE_MCPIO_UBICACION           2000 non-null   object
#  52  COLE_COD_DEPTO_UBICACION       2000 non-null   int64
#  53  COLE_DEPTO_UBICACION           2000 non-null   object
#  54  ESTU_PRIVADO_LIBERTAD          2000 non-null   object
#  55  ESTU_COD_MCPIO_PRESENTACION    2000 non-null   int64
#  56  ESTU_MCPIO_PRESENTACION        2000 non-null   object
#  57  ESTU_DEPTO_PRESENTACION        2000 non-null   object
#  58  ESTU_COD_DEPTO_PRESENTACION    2000 non-null   int64
#  59  PUNT_LECTURA_CRITICA           2000 non-null   int64
#  60  PERCENTIL_LECTURA_CRITICA      2000 non-null   int64
#  61  DESEMP_LECTURA_CRITICA         2000 non-null   int64
#  62  PUNT_MATEMATICAS               1995 non-null   float64
#  63  PERCENTIL_MATEMATICAS          2000 non-null   int64
#  64  DESEMP_MATEMATICAS             2000 non-null   int64
#  65  PUNT_C_NATURALES               2000 non-null   int64
#  66  PERCENTIL_C_NATURALES          2000 non-null   int64
#  67  DESEMP_C_NATURALES             2000 non-null   int64
#  68  PUNT_SOCIALES_CIUDADANAS       2000 non-null   int64
#  69  PERCENTIL_SOCIALES_CIUDADANAS  2000 non-null   int64
#  70  DESEMP_SOCIALES_CIUDADANAS     2000 non-null   int64
#  71  PUNT_INGLES                    1995 non-null   float64
#  72  PERCENTIL_INGLES               2000 non-null   int64
#  73  DESEMP_INGLES                  2000 non-null   object
#  74  PUNT_GLOBAL                    2000 non-null   int64
#  75  PERCENTIL_GLOBAL               2000 non-null   int64
#  76  ESTU_INSE_INDIVIDUAL           1943 non-null   float64
#  77  ESTU_NSE_INDIVIDUAL            1943 non-null   float64
#  78  ESTU_NSE_ESTABLECIMIENTO       2000 non-null   int64
#  79  ESTU_ESTADOINVESTIGACION       2000 non-null   object
#  80  ESTU_GENERACION-E              2000 non-null   object
# dtypes: float64(6), int64(23), object(52)
# memory usage: 1.2+ MB
# None
#
# Primeras filas:
#   ESTU_TIPODOCUMENTO ESTU_NACIONALIDAD ESTU_GENERO ESTU_FECHANACIMIENTO  \
# 0                 TI          COLOMBIA           F       4/29/2004 0:00
# 1                 CC          COLOMBIA           M       9/11/2002 0:00
# 2                 TI          COLOMBIA           F      10/11/2002 0:00
# 3                 TI          COLOMBIA           F       2/25/2004 0:00
# 4                 TI          COLOMBIA           F       7/27/2002 0:00
#
#    PERIODO  ESTU_CONSECUTIVO ESTU_ESTUDIANTE ESTU_PAIS_RESIDE ESTU_TIENEETNIA  \
# 0    20204  SB11202040028652      ESTUDIANTE         COLOMBIA              No
# 1    20204  SB11202040136621      ESTUDIANTE         COLOMBIA              No
# 2    20204  SB11202040089598      ESTUDIANTE         COLOMBIA              No
# 3    20204  SB11202040034744      ESTUDIANTE         COLOMBIA              No
# 4    20204  SB11202040035751      ESTUDIANTE         COLOMBIA              No
#
#   ESTU_DEPTO_RESIDE  ...  PUNT_INGLES PERCENTIL_INGLES  DESEMP_INGLES  \
# 0           CORDOBA  ...         40.0               31             A-
# 1            BOYACA  ...         52.0               75             A1
# 2           CORDOBA  ...         49.0               66             A1
# 3            BOGOTÁ  ...         68.0               94             B1
# 4            TOLIMA  ...         79.0               99             B+
#
#   PUNT_GLOBAL PERCENTIL_GLOBAL ESTU_INSE_INDIVIDUAL ESTU_NSE_INDIVIDUAL  \
# 0         182                8            36.415305                 1.0
# 1         322               93            55.298911                 3.0
# 2         220               31            44.642095                 2.0
# 3         328               94            59.780326                 3.0
# 4         360               99            70.067352                 4.0
#
#   ESTU_NSE_ESTABLECIMIENTO ESTU_ESTADOINVESTIGACION         ESTU_GENERACION-E
# 0                        2                 PUBLICAR  GENERACION E - GRATUIDAD
# 1                        3                 PUBLICAR  GENERACION E - GRATUIDAD
# 2                        2                 PUBLICAR                        NO
# 3                        3                 PUBLICAR                        NO
# 4                        4                 PUBLICAR                        NO
#
# [5 rows x 81 columns]
#
# Estadísticas descriptivas:
#        PERIODO  ESTU_COD_RESIDE_DEPTO  ESTU_COD_RESIDE_MCPIO  \
# count   2000.0            2000.000000            2000.000000
# mean   20204.0              32.937000           33172.703500
# std        0.0              26.314621           26339.341714
# min    20204.0               5.000000            5001.000000
# 25%    20204.0              11.000000           11001.000000
# 50%    20204.0              23.000000           23068.000000
# 75%    20204.0              54.000000           54001.500000
# max    20204.0              99.000000           99773.000000
#
#        COLE_CODIGO_ICFES  COLE_COD_DANE_ESTABLECIMIENTO  COLE_COD_DANE_SEDE  \
# count        2000.000000                   2.000000e+03        2.000000e+03
# mean       298273.542000                   1.996396e+11        1.995382e+11
# std        290805.030483                   9.069614e+10        9.069596e+10
# min           125.000000                   1.050010e+11        1.050010e+11
# 25%         63005.500000                   1.170010e+11        1.170010e+11
# 50%        144600.000000                   1.707105e+11        1.707445e+11
# 75%        669978.000000                   2.764030e+11        2.762368e+11
# max        751990.000000                   8.470010e+11        8.470010e+11
#
#        COLE_COD_MCPIO_UBICACION  COLE_COD_DEPTO_UBICACION  \
# count               2000.000000                2000.00000
# mean               33164.493500                  32.92950
# std                26351.733492                  26.32763
# min                 5001.000000                   5.00000
# 25%                11001.000000                  11.00000
# 50%                23068.000000                  23.00000
# 75%                54001.000000                  54.00000
# max                99773.000000                  99.00000
#
#        ESTU_COD_MCPIO_PRESENTACION  ESTU_COD_DEPTO_PRESENTACION  ...  \
# count                  2000.000000                  2000.000000  ...
# mean                  33162.373500                    32.945500  ...
# std                   26419.208325                    26.390259  ...
# min                    5001.000000                     5.000000  ...
# 25%                   11001.000000                    11.000000  ...
# 50%                   23001.000000                    23.000000  ...
# 75%                   54001.000000                    54.000000  ...
# max                   99773.000000                    99.000000  ...
#
#        PUNT_SOCIALES_CIUDADANAS  PERCENTIL_SOCIALES_CIUDADANAS  \
# count               2000.000000                    2000.000000
# mean                  48.330500                      50.415000
# std                   11.956829                      28.852314
# min                   21.000000                       1.000000
# 25%                   39.000000                      26.000000
# 50%                   48.000000                      50.000000
# 75%                   57.000000                      76.000000
# max                  100.000000                     100.000000
#
#        DESEMP_SOCIALES_CIUDADANAS  PUNT_INGLES  PERCENTIL_INGLES  PUNT_GLOBAL  \
# count                 2000.000000  1995.000000       2000.000000  2000.000000
# mean                     2.030500    46.605013         49.690500   248.898000
# std                      0.827594    11.115261         28.623004    48.310709
# min                      1.000000     0.000000          1.000000    57.000000
# 25%                      1.000000    39.000000         25.000000   212.000000
# 50%                      2.000000    45.000000         50.000000   247.000000
# 75%                      3.000000    52.000000         74.000000   281.250000
# max                      4.000000   100.000000        100.000000   432.000000
#
#        PERCENTIL_GLOBAL  ESTU_INSE_INDIVIDUAL  ESTU_NSE_INDIVIDUAL  \
# count       2000.000000           1943.000000          1943.000000
# mean          50.535000             51.096044             2.432836
# std           28.613548              9.367186             0.840830
# min            1.000000             19.074828             1.000000
# 25%           25.000000             44.328572             2.000000
# 50%           51.000000             50.931662             2.000000
# 75%           75.000000             57.170813             3.000000
# max          100.000000             80.919015             4.000000
#
#        ESTU_NSE_ESTABLECIMIENTO
# count               2000.000000
# mean                   2.430000
# std                    0.641331
# min                    1.000000
# 25%                    2.000000
# 50%                    2.000000
# 75%                    3.000000
# max                    4.000000
#
# [8 rows x 29 columns]

# %% [markdown]
# 3. Limpieza de los datos

# %%
# Revisar valores nulos
print(df.isnull().sum())

# Rellenar valores nulos con la media de cada columna numérica
df.fillna(df.mean(numeric_only=True), inplace=True)

# Confirmar que no quedan nulos
print('\nValores nulos tras la imputación:')
print(df.isnull().sum())
# Out:
# ESTU_TIPODOCUMENTO           0
# ESTU_NACIONALIDAD            0
# ESTU_GENERO                  0
# ESTU_FECHANACIMIENTO         0
# PERIODO                      0
#                             ..
# ESTU_INSE_INDIVIDUAL        57
# ESTU_NSE_INDIVIDUAL         57
# ESTU_NSE_ESTABLECIMIENTO     0
# ESTU_ESTADOINVESTIGACION     0
# ESTU_GENERACION-E            0
# Length: 81, dtype: int64
#
# Valores nulos tras la imputación:
# ESTU_TIPODOCUMENTO          0
# ESTU_NACIONALIDAD           0
# ESTU_GENERO                 0
# ESTU_FECHANACIMIENTO        0
# PERIODO                     0
#                            ..
# ESTU_INSE_INDIVIDUAL        0
# ESTU_NSE_INDIVIDUAL         0
# ESTU_NSE_ESTABLECIMIENTO    0
# ESTU_ESTADOINVESTIGACION    0
# ESTU_GENERACION-E           0
# Length: 81, dtype: int64

# %% [markdown]
# 4. Análisis exploratorio: Se tomarán para análisis de variables numéricas solo las que correspondan a puntajes de la prueba

# %%
columnas_puntajes = [
    'PUNT_LECTURA_CRITICA',
    'PUNT_MATEMATICAS',
    'PUNT_C_NATURALES',
    'PUNT_SOCIALES_CIUDADANAS',
    'PUNT_INGLES',
    'PUNT_GLOBAL'
]

for columna in columnas_puntajes:
    plt.figure(figsize=(8, 4))
    sns.histplot(df[columna], kde=True, bins=30)
    plt.title(f'Distribución de {columna}')
    plt.xlabel(columna)
    plt.ylabel('Frecuencia')
    plt.show()

# %% [markdown]
# 4.1 Aplicaremos test de normalidad para erificar si son distribuciones normales

# %% [markdown]
# 4.1 Gráficos QQ

# %%
def graficar_qq(datos, nombre):
    plt.figure(figsize=(6, 6))
    stats.probplot(datos, dist="norm", plot=plt)
    plt.title(f"Gráfico Q-Q para {nombre}")
    plt.xlabel("Cuantiles teóricos")
    plt.ylabel("Cuantiles observados")
    plt.grid(True)
    plt.show()

for col in columnas_puntajes:
    if col in df.columns:
        graficar_qq(df[col].dropna(), col)
    else:
        print(f"La columna {col} no está en el DataFrame.")

# %% [markdown]
# 4.1 Matriz de correlación entre puntajes

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro, kstest, anderson, jarque_bera

# Lista de variables de puntaje
columnas_puntajes = [
    'PUNT_LECTURA_CRITICA',
    'PUNT_MATEMATICAS',
    'PUNT_C_NATURALES',
    'PUNT_SOCIALES_CIUDADANAS',
    'PUNT_INGLES',
    'PUNT_GLOBAL'
]

# Función para verificar normalidad (al menos 3 tests deben indicar normalidad)
def es_normal(datos):
    datos = datos.dropna()
    # Shapiro-Wilk
    _, p_sw = shapiro(datos)
    # Kolmogorov-Smirnov
    media, desv = np.mean(datos), np.std(datos)
    _, p_ks = kstest(datos, "norm", args=(media, desv))
    # Anderson-Darling
    resultado_ad = anderson(datos)
    ad_normal = resultado_ad.statistic < resultado_ad.critical_values[2]  # 5%
    # Jarque-Bera
    _, p_jb = jarque_bera(datos)
    normales = [
        p_sw > 0.05,
        p_ks > 0.05,
        ad_normal,
        p_jb > 0.05
    ]
    return normales.count(True) >= 3

# Verificar normalidad de cada variable
normalidad = {}
for col in columnas_puntajes:
    if col in df.columns:
        normalidad[col] = es_normal(df[col])
    else:
        normalidad[col] = False

# Seleccionar el método de correlación adecuado
if all(normalidad.values()):
    metodo_corr = 'pearson'
    print("Todas las variables son normales. Se usará correlación de Pearson.")
else:
    metodo_corr = 'spearman'
    print("Alguna variable NO es normal. Se usará correlación de Spearman.")

# Calcular la matriz de correlación
matriz_corr = df[columnas_puntajes].corr(method=metodo_corr)

# Graficar la matriz de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_corr, annot=True, cmap='Blues', vmin=-1, vmax=1)
plt.title(f'Matriz de correlación de puntajes ({metodo_corr.capitalize()})')
plt.show()
# Out:
# Alguna variable NO es normal. Se usará correlación de Spearman.

# %%
# Se buscan datos atípicos y se eliminan usando la técnica de rango intercuartílico

# Calcular Q1, Q3 e IQR para las columnas de puntaje
Q1 = df[columnas_puntajes].quantile(0.25)
Q3 = df[columnas_puntajes].quantile(0.75)
IQR = Q3 - Q1

# Diccionario para almacenar la cantidad de valores atípicos eliminados por columna
outliers_removed = {}

# Crear una copia del DataFrame para el filtrado
filtered_df = df.copy()

for col in columnas_puntajes:
    initial_count = filtered_df.shape[0]
    # Filtrar valores atípicos según IQR para la columna actual
    mask = (filtered_df[col] >= (Q1[col] - 1.5 * IQR[col])) & (filtered_df[col] <= (Q3[col] + 1.5 * IQR[col]))
    filtered_df = filtered_df[mask]
    final_count = filtered_df.shape[0]
    outliers_removed[col] = initial_count - final_count

# Imprimir la cantidad de valores atípicos eliminados por columna
for col, count in outliers_removed.items():
    print(f"Columna '{col}': {count} valores atípicos eliminados")

# Imprimir cuántos valores quedan después del filtrado
print(f"\nEl DataFrame filtrado tiene {filtered_df.shape[0]} filas después de eliminar los outliers.")

# Si quieres seguir trabajando con el DataFrame filtrado:
df_puntajes_filtrado = filtered_df.copy()
# Out:
# Columna 'PUNT_LECTURA_CRITICA': 5 valores atípicos eliminados
# Columna 'PUNT_MATEMATICAS': 5 valores atípicos eliminados
# Columna 'PUNT_C_NATURALES': 2 valores atípicos eliminados
# Columna 'PUNT_SOCIALES_CIUDADANAS': 3 valores atípicos eliminados
# Columna 'PUNT_INGLES': 71 valores atípicos eliminados
# Columna 'PUNT_GLOBAL': 0 valores atípicos eliminados
#
# El DataFrame filtrado tiene 1914 filas después de eliminar los outliers.

# %% [markdown]
# Se ejecutan de nuevo test de normalidad para verificar si después de eliminar outliers son variables que siguen la distribución normal

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import shapiro, kstest, anderson, jarque_bera

# Lista de variables de puntaje
columnas_puntajes = [
    'PUNT_LECTURA_CRITICA',
    'PUNT_MATEMATICAS',
    'PUNT_C_NATURALES',
    'PUNT_SOCIALES_CIUDADANAS',
    'PUNT_INGLES',
    'PUNT_GLOBAL'
]

# Función para verificar normalidad (al menos 3 tests deben indicar normalidad)
def es_normal(datos):
    datos = datos.dropna()
    # Shapiro-Wilk
    _, p_sw = shapiro(datos)
    # Kolmogorov-Smirnov
    media, desv = np.mean(datos), np.std(datos)
    _, p_ks = kstest(datos, "norm", args=(media, desv))
    # Anderson-Darling
    resultado_ad = anderson(datos)
    ad_normal = resultado_ad.statistic < resultado_ad.critical_values[2]  # 5%
    # Jarque-Bera
    _, p_jb = jarque_bera(datos)
    normales = [
        p_sw > 0.05,
        p_ks > 0.05,
        ad_normal,
        p_jb > 0.05
    ]
    return normales.count(True) >= 3

# Verificar normalidad de cada variable en df_puntajes_filtrado
normalidad = {}
for col in columnas_puntajes:
    if col in df_puntajes_filtrado.columns:
        normalidad[col] = es_normal(df_puntajes_filtrado[col])
    else:
        normalidad[col] = False

# Seleccionar el método de correlación adecuado
if all(normalidad.values()):
    metodo_corr = 'pearson'
    print("Todas las variables son normales. Se usará correlación de Pearson.")
else:
    metodo_corr = 'spearman'
    print("Alguna variable NO es normal. Se usará correlación de Spearman.")

# Calcular la matriz de correlación
matriz_corr = df_puntajes_filtrado[columnas_puntajes].corr(method=metodo_corr)

# Graficar la matriz de correlación
plt.figure(figsize=(8, 6))
sns.heatmap(matriz_corr, annot=True, cmap='Blues', vmin=-1, vmax=1)
plt.title(f'Matriz de correlación de puntajes ({metodo_corr.capitalize()})')
plt.show()
# Out:
# Alguna variable NO es normal. Se usará correlación de Spearman.

# %%
import matplotlib.pyplot as plt

# Lista de variables categóricas a graficar
categorical_vars = [
    'ESTU_TIPODOCUMENTO', 'ESTU_NACIONALIDAD', 'ESTU_GENERO', 'ESTU_TIENEETNIA',
    'ESTU_DEPTO_RESIDE', 'FAMI_ESTRATOVIVIENDA', 'FAMI_EDUCACIONPADRE',
    'FAMI_EDUCACIONMADRE', 'FAMI_TIENEINTERNET', 'COLE_GENERO', 'COLE_NATURALEZA',
    'COLE_CALENDARIO', 'COLE_BILINGUE', 'COLE_AREA_UBICACION', 'COLE_JORNADA'
]

for col in categorical_vars:
    if col in df.columns:
        # Gráfico de barras
        plt.figure(figsize=(10, 4))
        df[col].value_counts(dropna=False).plot(kind='bar', color='skyblue')
        plt.title(f'Distribución de {col}')
        plt.xlabel(col)
        plt.ylabel('Frecuencia')
        plt.xticks(rotation=45, ha='right')
        plt.tight_layout()
        plt.show()

        # Gráfico de torta (pastel)
        plt.figure(figsize=(6, 6))
        df[col].value_counts(dropna=False).plot.pie(autopct='%1.1f%%', startangle=90, counterclock=False)
        plt.title(f'Proporción de {col}')
        plt.ylabel('')
        plt.tight_layout()
        plt.show()
    else:
        print(f"La columna {col} no está presente en el DataFrame.")

# %%
# Filtrar filas donde COLE_JORNADA es "MAÑANA"
datos_manana = filtered_df[filtered_df['COLE_JORNADA'] == 'MAÑANA']

# Calcular la media de PUNT_MATEMATICAS para esa condición
media_punt_mat = datos_manana['PUNT_MATEMATICAS'].mean()

# Contar cuántos datos hay (no nulos) en PUNT_MATEMATICAS para esa condición
cantidad_datos = datos_manana['PUNT_MATEMATICAS'].count()

print(f"Media de PUNT_MATEMATICAS para jornada MAÑANA: {media_punt_mat}")
print(f"Cantidad de datos disponibles: {cantidad_datos}")

# Calcular la desviación estándar de PUNT_MATEMATICAS para jornada "MAÑANA"
desviacion_estandar = datos_manana['PUNT_MATEMATICAS'].std()

print(f"Desviación estándar de PUNT_MATEMATICAS para jornada MAÑANA: {desviacion_estandar}")

# Desviación estándar poblacional para toda la variable PUNT_MATEMATICAS en filtered_df
desviacion_estandar_poblacion_total = filtered_df['PUNT_MATEMATICAS'].std(ddof=0)

# Media y conteo también para referencia
media_total = filtered_df['PUNT_MATEMATICAS'].mean()
cantidad_total = filtered_df['PUNT_MATEMATICAS'].count()

print(f"Media total de PUNT_MATEMATICAS: {media_total}")
print(f"Cantidad total de datos: {cantidad_total}")
print(f"Desviación estándar poblacional total: {desviacion_estandar_poblacion_total}")
# Out:
# Media de PUNT_MATEMATICAS para jornada MAÑANA: 51.145591786254144
# Cantidad de datos disponibles: 766
# Desviación estándar de PUNT_MATEMATICAS para jornada MAÑANA: 10.557833262566126
# Media total de PUNT_MATEMATICAS: 50.6124912594967
# Cantidad total de datos: 1914
# Desviación estándar poblacional total: 10.762612107498281
